# %% [markdown]
# # Car price predict

# %%
from PIL import Image
import matplotlib.pyplot as plt  # For displaying the image using matplotlib

# Define the image file path using a raw string (prefix with 'r')
image_path = "C:/Users/ssour/Downloads/car-neon-chevrolet-corvette-race-cars-hd-wallpaper-preview.jpg"

# Open an image file
img = Image.open(image_path)

# Display the image using matplotlib
plt.imshow(img)
plt.axis('off')  # Turn off axes for image display
plt.show()

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Datasets

# %%
df=pd.read_csv("C:/Users/ssour/OneDrive/Documents/drgf.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0        Dealer       Manual      0         NaN          NaN          NaN
# 1        Dealer       Manual      0         NaN          NaN          NaN
# 2        Dealer       Manual      0         NaN          NaN          NaN
# 3        Dealer       Manual      0         NaN          NaN          NaN
# 4        Dealer       Manual      0         NaN          NaN          NaN
# ..          ...          ...    ...         ...          ...          ...
# 296      Dealer       Manual      0         NaN          NaN          NaN
# 297      Dealer       Manual      0         NaN          NaN          NaN
# 298      Dealer       Manual      0         NaN          NaN          NaN
# 299      Dealer       Manual      0         NaN          NaN          NaN
# 300      Dealer       Manual      0         NaN          NaN          NaN
#
# [301 rows x 12 columns]

# %%
# Drop specified columns from DataFrame
df.drop(["Unnamed: 9", "Unnamed: 10", "Unnamed: 11"], axis=1, inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0
# 7      Dealer       Manual      0
# 8      Dealer       Manual      0
# 9      Dealer       Manual      0

# %%
df.tail(10)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# 295      Dealer       Manual      0
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Checking the dimension of the dataset
df.shape
# Out:
# (301, 9)

# %% [raw]
# Here we can see that in this datasets there are 301 rows and 9 columns

# %%
print("The dimensions of the dataset: ",df.shape)
print("The column headers :",df.columns)
# Out:
# The dimensions of the dataset:  (301, 9)
# The column headers : Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# checking the types of columns
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.set_index('Year',inplace = True)

# %%
# Now checking null values in this dataset
df.isnull().sum()
# Out:
# Car_Name         0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
#Now checking null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: ylabel='Year'>

# %% [raw]
# No null values present in this datasets

# %%
# Count values of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64
#
#
# 0.45     8
# 0.60     8
# 5.25     7
# 4.50     7
# 0.20     6
#         ..
# 3.80     1
# 3.45     1
# 5.90     1
# 35.00    1
# 11.50    1
# Name: Selling_Price, Length: 156, dtype: int64
#
#
# 9.40     15
# 13.60    13
# 5.70      8
# 4.43      7
# 1.47      7
#          ..
# 18.54     1
# 7.27      1
# 15.04     1
# 10.21     1
# 12.50     1
# Name: Present_Price, Length: 147, dtype: int64
#
#
# 45000    9
# 15000    9
# 40000    5
# 35000    5
# 50000    5
#         ..
# 1400     1
# 1200     1
# 4100     1
# 21700    1
# 5464     1
# Name: Kms_Driven, Length: 206, dtype: int64
#
#
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
#
#
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64
#
#
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64
#
#
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
# Separating Numerical and Categorical Columns

# Checking for categorical Coumns
categorical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns: ",categorical_col)
print("\n")

# Checking for numerical columns
numerical_col = []
for i  in df.dtypes.index:
    if df.dtypes[i]!= "object":
        numerical_col.append(i)
print("Numerical Columns: ",numerical_col)
# Out:
# Categorical Columns:  ['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission']
#
#
# Numerical Columns:  ['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
# Checking number of unique values in ech column
df.nunique().to_frame("No. of unique values")
# Out:
#                No. of unique values
# Car_Name                         98
# Selling_Price                   156
# Present_Price                   147
# Kms_Driven                      206
# Fuel_Type                         3
# Seller_Type                       2
# Transmission                      2
# Owner                             3

# %% [markdown]
# # Visualize the data

# %%
# visualize the number of  people
ax=sns.countplot(x='Fuel_Type',data=df)
print(df['Fuel_Type'].value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %% [raw]
# Here we can see most of the people are liking the car whose fuel type is petrol

# %%
# visualize the number of  people
ax=sns.countplot(x='Seller_Type',data=df)
print(df['Seller_Type'].value_counts())
# Out:
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64

# %% [raw]
# Here we can see that seller type dealer is more as compared to individual

# %%
# visualize the number of  people
ax=sns.countplot(x='Transmission',data=df)
print(df['Transmission'].value_counts())
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
# visualize the number of  people
ax=sns.countplot(x='Owner',data=df)
print(df['Owner'].value_counts())
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %% [markdown]
# # Data Distributed

# %%
plotnumber = 1  # Initialize subplot number
for col in numerical_col:
    if plotnumber <= 4:  # Ensure plotnumber is within valid range (1 to 4 for a 2x2 grid)
        ax = plt.subplot(2, 2, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plotnumber += 1  # Increment plotnumber for the next subplot
    else:
        break  # Exit loop if plotnumber exceeds the maximum number of subplots

plt.tight_layout()  # Adjust subplot layout to prevent overlap
plt.show()  # Display the figure with subplots

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue = "Fuel_Type",palette="Dark2")
plt.show()

# %%
sns.pairplot(df,hue = "Seller_Type",palette="Dark2")
plt.show()

# %%
sns.pairplot(df,hue = "Transmission",palette="Dark2")
plt.show()

# %% [markdown]
# # Checking For Outliers

# %%
num_numerical_cols = len(numerical_col)
num_rows = 5  # Number of rows in the subplot grid
num_cols = 4  # Number of columns in the subplot grid
total_subplots = num_rows * num_cols

# Create a new figure and set its size
plt.figure(figsize=(20, 16), facecolor="white")  # Adjust the figure size as needed

# Iterate over numerical columns and create subplots for boxplots
plotnumber = 1
for col in numerical_col:
    if plotnumber <= total_subplots:
        # Create subplot at the specified position
        ax = plt.subplot(num_rows, num_cols, plotnumber)
        
        # Plot boxplot for the current column using seaborn
        sns.boxplot(x=df[col], palette="Set2_r", ax=ax)
        
        # Customize subplot labels and ticks
        plt.xlabel(col, fontsize=15)
        plt.ylabel("")  # Clear y-axis label
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(fontsize=10)
        
        plotnumber += 1  # Increment plotnumber for the next subplot

# Adjust layout to prevent overlap and improve readability
plt.tight_layout()
plt.show()  # Display the figure with subplots

# %% [raw]
# Here is the selling price is my target variable .Almost all columns contains outliers

# %% [markdown]
# # Using iQR method to remove outliers

# %%
import pandas as pd

# Assuming df is your DataFrame containing the relevant columns

# Calculate IQR
columns_of_interest = ['Car_Name', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']
Q1 = df[columns_of_interest].quantile(0.25)
Q3 = df[columns_of_interest].quantile(0.75)
IQR = Q3 - Q1

# Determine outliers based on IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

# Remove outliers
df1 = df[~((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

# Print cleaned DataFrame
print("DataFrame after removing outliers:")
print(df1)

# Optional: Print removed outliers
print("\nOutliers removed:")
print(outliers)
# Out:
# DataFrame after removing outliers:
#      Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59       27000    Petrol      Dealer
# 2013      sx4           4.75           9.54       43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85        6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15        5200    Petrol      Dealer
# 2014    swift           4.60           6.87       42450    Diesel      Dealer
# ...       ...            ...            ...         ...       ...         ...
# 2016     city           9.50          11.60       33988    Diesel      Dealer
# 2015     brio           4.00           5.90       60000    Petrol      Dealer
# 2009     city           3.35          11.00       87934    Petrol      Dealer
# 2017     city          11.50          12.50        9000    Diesel      Dealer
# 2016     brio           5.30           5.90        5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# 2017       Manual      0
# 2011       Manual      0
# 2014       Manual      0
# ...           ...    ...
# 2016       Manual      0
# 2015       Manual      0
# 2009       Manual      0
# 2017       Manual      0
# 2016       Manual      0
#
# [272 rows x 8 columns]
#
# Outliers removed:
#                 Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Year
# 2003                 800           0.35           2.28      127000    Petrol
# 2012            fortuner          14.90          30.61      104707    Diesel
# 2015            fortuner          23.00          30.61       40000    Diesel
# 2013            fortuner          16.00          30.61      135000    Diesel
# 2014             etios g           4.10           6.80       39485    Petrol
# 2014            fortuner          19.99          35.96       41000    Diesel
# 2014            fortuner          18.75          35.96       78000    Diesel
# 2015            fortuner          23.50          35.96       47000    Diesel
# 2017            fortuner          33.00          36.23        6000    Diesel
# 2017              innova          19.75          23.15       11000    Petrol
# 2004             corolla           1.50          12.35      135154    Petrol
# 2012            fortuner          14.50          30.61       89000    Diesel
# 2017              innova          23.00          25.39       15000    Diesel
# 2005              innova           3.49          13.46      197176    Diesel
# 2006               camry           2.50          23.73      142000    Petrol
# 2010        land cruiser          35.00          92.60       78000    Diesel
# 2015            fortuner          23.00          30.61       40000    Diesel
# 2016              innova          20.75          25.39       29000    Diesel
# 2014      Hyosung GT250R           1.35           3.45       16500    Petrol
# 2010       Honda Karizma           0.31           1.05      213000    Petrol
# 2008    Bajaj Pulsar 150           0.25           0.75       26000    Petrol
# 2012  Bajaj Discover 125           0.20           0.57       25000    Petrol
# 2007           Hero Hunk           0.20           0.75       49000    Petrol
# 2013  Hero  Ignitor Disc           0.20           0.65       24000    Petrol
# 2008           Activa 3g           0.17           0.52      500000    Petrol
# 2011  Bajaj Discover 125           0.15           0.57       35000    Petrol
# 2010                 i20           3.25           6.79       58000    Diesel
# 2016           grand i10           5.25           5.70        3493    Petrol
# 2015               xcent           4.75           7.13       35866    Petrol
#
#      Seller_Type Transmission  Owner
# Year
# 2003  Individual       Manual      0
# 2012      Dealer    Automatic      0
# 2015      Dealer    Automatic      0
# 2013  Individual    Automatic      0
# 2014      Dealer       Manual      1
# 2014      Dealer    Automatic      0
# 2014      Dealer    Automatic      0
# 2015      Dealer    Automatic      0
# 2017      Dealer    Automatic      0
# 2017      Dealer    Automatic      0
# 2004      Dealer    Automatic      0
# 2012      Dealer    Automatic      0
# 2017      Dealer    Automatic      0
# 2005      Dealer       Manual      0
# 2006  Individual    Automatic      3
# 2010      Dealer       Manual      0
# 2015      Dealer    Automatic      0
# 2016      Dealer    Automatic      0
# 2014  Individual       Manual      1
# 2010  Individual       Manual      0
# 2008  Individual       Manual      1
# 2012  Individual       Manual      1
# 2007  Individual       Manual      1
# 2013  Individual       Manual      1
# 2008  Individual    Automatic      0
# 2011  Individual       Manual      1
# 2010      Dealer       Manual      1
# 2016      Dealer       Manual      1
# 2015      Dealer       Manual      1

# %%
import pandas as pd

# Assuming df is your DataFrame containing the relevant columns

# Calculate IQR
columns_of_interest =['Car_Name', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']
Q1 = df1[columns_of_interest].quantile(0.25)
Q3 = df1[columns_of_interest].quantile(0.75)
IQR = Q3 - Q1

# Determine outliers based on IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df1[((df1[columns_of_interest] < lower_bound) | (df1[columns_of_interest] > upper_bound)).any(axis=1)]

# Remove outliers
df1 = df1[~((df1[columns_of_interest] < lower_bound) | (df1[columns_of_interest] > upper_bound)).any(axis=1)]

# Print cleaned DataFrame
print("DataFrame after removing outliers:")
print(df1)

# Optional: Print removed outliers
print("\nOutliers removed:")
print(outliers)
# Out:
# DataFrame after removing outliers:
#      Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59       27000    Petrol      Dealer
# 2013      sx4           4.75           9.54       43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85        6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15        5200    Petrol      Dealer
# 2014    swift           4.60           6.87       42450    Diesel      Dealer
# ...       ...            ...            ...         ...       ...         ...
# 2016     city           9.50          11.60       33988    Diesel      Dealer
# 2015     brio           4.00           5.90       60000    Petrol      Dealer
# 2009     city           3.35          11.00       87934    Petrol      Dealer
# 2017     city          11.50          12.50        9000    Diesel      Dealer
# 2016     brio           5.30           5.90        5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# 2017       Manual      0
# 2011       Manual      0
# 2014       Manual      0
# ...           ...    ...
# 2016       Manual      0
# 2015       Manual      0
# 2009       Manual      0
# 2017       Manual      0
# 2016       Manual      0
#
# [269 rows x 8 columns]
#
# Outliers removed:
#               Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Year
# 2010     corolla altis           5.25          22.83       80000    Petrol
# 2008     corolla altis           4.00          22.78       89000    Petrol
# 2006  Bajaj Pulsar 150           0.10           0.75       92233    Petrol
#
#      Seller_Type Transmission  Owner
# Year
# 2010      Dealer    Automatic      0
# 2008      Dealer    Automatic      0
# 2006  Individual       Manual      0

# %%
num_numerical_cols = len(numerical_col)
num_rows = 5  # Number of rows in the subplot grid
num_cols = 4  # Number of columns in the subplot grid
total_subplots = num_rows * num_cols

# Create a new figure and set its size
plt.figure(figsize=(20, 16), facecolor="white")  # Adjust the figure size as needed

# Iterate over numerical columns and create subplots for boxplots
plotnumber = 1
for col in numerical_col:
    if plotnumber <= total_subplots:
        # Create subplot at the specified position
        ax = plt.subplot(num_rows, num_cols, plotnumber)
        
        # Plot boxplot for the current column using seaborn
        sns.boxplot(x=df1[col], palette="Set2_r", ax=ax)
        
        # Customize subplot labels and ticks
        plt.xlabel(col, fontsize=15)
        plt.ylabel("")  # Clear y-axis label
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(fontsize=10)
        
        plotnumber += 1  # Increment plotnumber for the next subplot

# Adjust layout to prevent overlap and improve readability
plt.tight_layout()
plt.show()  # Display the figure with subplots

# %% [raw]
# Now we can see that we removed all extra outliers

# %% [markdown]
# # Now Checking Skewness

# %%
# Encoding categorical columns using OrdinalEnocoder
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df1.columns:
    if df1[i].dtypes =="object":
        df1[i]=OE.fit_transform(df1[i].values.reshape(-1,1))
df1
# Out:
#       Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Year
# 2014      82.0           3.35           5.59       27000        2.0
# 2013      85.0           4.75           9.54       43000        1.0
# 2017      62.0           7.25           9.85        6900        2.0
# 2011      88.0           2.85           4.15        5200        2.0
# 2014      84.0           4.60           6.87       42450        1.0
# ...        ...            ...            ...         ...        ...
# 2016      63.0           9.50          11.60       33988        1.0
# 2015      61.0           4.00           5.90       60000        2.0
# 2009      63.0           3.35          11.00       87934        2.0
# 2017      63.0          11.50          12.50        9000        1.0
# 2016      61.0           5.30           5.90        5464        2.0
#
#       Seller_Type  Transmission  Owner
# Year
# 2014          0.0           1.0      0
# 2013          0.0           1.0      0
# 2017          0.0           1.0      0
# 2011          0.0           1.0      0
# 2014          0.0           1.0      0
# ...           ...           ...    ...
# 2016          0.0           1.0      0
# 2015          0.0           1.0      0
# 2009          0.0           1.0      0
# 2017          0.0           1.0      0
# 2016          0.0           1.0      0
#
# [269 rows x 8 columns]

# %%
# Now all data are converted into numercial form so no we check skewness
df1.skew()
# Out:
# Car_Name        -0.791226
# Selling_Price    1.068883
# Present_Price    0.704527
# Kms_Driven       0.475110
# Fuel_Type       -1.950128
# Seller_Type      0.635089
# Transmission    -2.981300
# Owner            0.000000
# dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(12, 10))

# Create a heatmap of the correlation matrix
sns.heatmap(df1.corr(), 
            annot=True,        # Show correlation values on the heatmap
            cmap="Blues",      # Set the color map to 'Blues'
            linewidths=0.1,    # Set width between cells
            linecolor='black', # Color of the lines separating cells
            fmt='.2f')       # Ensure cells are square-shaped

# Rotate y-axis labels to be horizontal
plt.yticks(rotation=0)

# Display the heatmap
plt.show()

# %%
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %% [markdown]
# # Checking How the data is ditributed

# %%
plt.figure(figsize=(20,25), facecolor = 'green')
plotnumber =1
for column in df1:
    if plotnumber <= 18:
        ax =plt.subplot(6,4,plotnumber)
        sns.distplot(df1[column],color = 'b')
        plt.xlabel(column,fontsize = 20)
    plotnumber += 1
plt.show()

# %% [markdown]
# # Split the target Features

# %%
# Separating the independent and target varaible into x and y
x = df1.drop(['Selling_Price'], axis=1)  # Features we remove price columns
y = df1['Selling_Price']    #  Here now the price is my target variable
print("Feature Dimensions= ",x.shape)
print("Label Dimensions",y.shape)
# Out:
# Feature Dimensions=  (269, 7)
# Label Dimensions (269,)

# %%
y.value_counts()
# Out:
# 0.60     8
# 0.45     8
# 4.50     7
# 5.25     5
# 0.40     5
#         ..
# 1.65     1
# 1.70     1
# 1.75     1
# 9.65     1
# 11.50    1
# Name: Selling_Price, Length: 139, dtype: int64

# %% [markdown]
# # Find the one of the best model

# %%
# importing libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor

# %%
# Finding the best random state
maxAccu = 0
maxRS = 0
for i in range(1, 200):
    # Splitting the data into train and test sets using current random state (i)
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, random_state=i)
    
    # Initializing and training the Gradient Boosting Regressor
    RFR = RandomForestRegressor()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Maximum r2 score is ",maxAccu,"on Random_State",maxRS)
# Out:
# Maximum r2 score is  0.9324535242039357 on Random_State 73

# %% [raw]
# Now we clear see that RandomForestRegressor is my best model

# %% [markdown]
# # Creating train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, random_state=73)

# %% [markdown]
# # Now Guessing Best Model

# %%
# Train the KNN regressor
RFR.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Make predictions
y_pred = RFR.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# Calculate R2 score
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# R2 Score: 0.9354046084765059
# Mean Squared Error: 0.7950845444444442

# %% [markdown]
# # Now saving the model using joblib

# %%
# Saving the model
import joblib
joblib.dump(RFR,"car_price_predict.pkl")
# Out:
# ['Medical_cost_insurance.pkl']

# %%
import pickle
filename = "car_price_predict.pkl"
pickle.dump(RFR, open(filename,'wb'))  #Saved model

# %% [markdown]
# # Predicting the saved model

# %%
load_model = pickle.load(open("car_price_predict.pkl",'rb'))
result = load_model.score(x_test,y_test)
print(result*100)
# Out:
# 93.54046084765059

# %% [markdown]
# # Conclusion

# %%
conclusion = pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                0       1       2       3      4       5     6       7      8   \
# Predicted  0.4522  7.5338  0.4851  8.9224  5.975  0.4248  8.34  5.1391  5.424
# Original   0.4500  8.9900  0.2000  8.6500  7.750  0.6500  6.25  4.5000  6.450
#
#                9   ...      71      72      73      74      75      76  \
# Predicted  0.3661  ...  0.7336  5.2445  6.8555  0.4241  0.7425  3.7858
# Original   0.2500  ...  0.9000  5.3000  8.3500  0.2500  0.7500  4.4000
#
#                77     78      79     80
# Predicted  5.5141  2.825  5.1216  3.745
# Original   6.5000  2.000  4.8000  3.450
#
# [2 rows x 81 columns]

# %%
import numpy as np

# Define input data (Car price characteristics)

input_data = np.array([[82.0,5.59,27000,2.0,0.0,1.0,0]])  # Example input data (single sample)

# Make prediction using the trained SVR model
prediction = RFR.predict(input_data)  # Use 'svr' for prediction
print("Input Data:", input_data)
print("The predicted Car price:", prediction)
# Out:
# Input Data: [[8.20e+01 5.59e+00 2.70e+04 2.00e+00 0.00e+00 1.00e+00 0.00e+00]]
# The predicted Car price: [3.7595]

# %% [raw]
# This is my Overall Prediction

# %% [markdown]
# # THANK YOU
